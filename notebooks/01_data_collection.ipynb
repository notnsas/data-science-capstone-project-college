# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/data-science-capstone-project-college/blob/main/notebooks/01_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1. Import & Installs Libraries**

# %% [markdown]
# Bagian ini bertujuan untuk menyiapkan lingkungan kerja dengan menginstal dan mengimpor library yang diperlukan untuk mengambil ulasan aplikasi dari Google Play Store.
#
# 1.  **Instalasi `google-play-scraper`**: Kode `!pip install google-play-scraper` menjalankan perintah untuk menginstal library `google-play-scraper`. Library ini menyediakan fungsi untuk berinteraksi dengan Google Play Store dan mengambil data seperti ulasan aplikasi.
# 2.  **Import Library**: Kode `from google_play_scraper import Sort, reviews` dan `import pandas as pd` mengimpor fungsi dan kelas yang spesifik dari library yang telah diinstal:
#     *   `Sort` dan `reviews` dari `google_play-scraper` digunakan untuk mengambil ulasan aplikasi dengan opsi penyortiran tertentu.
#     *   `pandas` diimpor sebagai `pd` untuk memudahkan manipulasi dan analisis data ulasan yang akan diambil, seperti mengubahnya menjadi DataFrame.

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.4 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import Sort, reviews
import pandas as pd

# %% [markdown]
# ***English Version:***
#
# This section aims to set up the working environment by installing and importing the necessary libraries to scrape app reviews from the Google Play Store.
#
# 1.  **Install `google-play-scraper`**: The code `!pip install google-play-scraper` runs the command to install the `google-play-scraper` library. This library provides functions to interact with the Google Play Store and retrieve data such as app reviews.
# 2.  **Import Libraries**: The code `from google_play_scraper import Sort, reviews` and `import pandas as pd` import specific functions and classes from the installed libraries:
#     *   `Sort` and `reviews` from `google_play-scraper` are used to fetch app reviews with specific sorting options.
#     *   `pandas` is imported as `pd` to facilitate the manipulation and analysis of the scraped review data, such as converting it into a DataFrame.

# %% [markdown]
# ## **2. Scrape Reviews**

# %% [markdown]
# Bagian ini berisi kode untuk mengambil ulasan aplikasi dari Google Play Store menggunakan library `google-play-scraper`.
#
# Kode berikut mengambil ulasan menggunakan fungsi `reviews`:
# - `app_id = 'com.whatsapp'`: Mendefinisikan ID paket aplikasi WhatsApp yang ulasannya akan diambil.
# - `scraped_reviews, _ = reviews(...)`: Memanggil fungsi `reviews` untuk mengambil ulasan. Fungsi ini mengembalikan dua nilai: daftar ulasan (`scraped_reviews`) dan token untuk mengambil halaman berikutnya (yang diabaikan dengan `_`).
# - `lang='id'`: Menetapkan bahasa ulasan yang diambil ke Bahasa Indonesia.
# - `country='id'`: Menetapkan negara asal ulasan yang diambil ke Indonesia.
# - `sort=Sort.NEWEST`: Mengurutkan ulasan berdasarkan yang terbaru. `Sort.NEWEST` berasal dari enum `Sort` yang diimpor.
# - `count=10000`: Menetapkan jumlah maksimum ulasan yang akan diambil sebanyak 10000.

# %%
# app_id = 'com.spotify.music'
# scraped_reviews, _ = reviews(
#     app_id,
#     lang='id', # defaults to 'en' can be change to 'id' or otherwise
#     country='id', # defaults to 'us' can be change to 'id' or otherwise
#     sort=Sort.RATING, # Use Sort.NEWEST instead of 'newest'
#     count=15000 # defaults to 100
# )

# %%
# app_id = 'com.spotify.music'
# countries = ['id', 'us', 'gb', 'au', 'ca', 'nz', 'ie', 'sg', 'hk', 'ke', 'ng', 'cm', 'bi', 'gh', 'in', 'pk', 'mw', 'ph', 'za', 'sd', 'ss', 'tz', 'ug', 'zm', 'zw', 'my', 'ae'] # Add country codes for the desired countries
# all_scraped_reviews = []

# for country_code in countries:
#   print(f"Scraping reviews for {country_code}...")
#   scraped_reviews, _ = reviews(
#       app_id,
#       lang='en', # Use English for these countries
#       country=country_code,
#       sort=Sort.NEWEST,
#       count=2000000 # Reduced count for demonstration, adjust as needed
#   )
#   all_scraped_reviews.extend(scraped_reviews)

# scraped_reviews_df = pd.DataFrame(all_scraped_reviews)
# display(scraped_reviews_df.head())
# Out:
# Scraping reviews for id...
# Scraping reviews for us...
# Scraping reviews for gb...
# Scraping reviews for au...
# Scraping reviews for ca...
# Scraping reviews for nz...

# %% [markdown]
# ## **3. Show the Data**

# %% [markdown]
# **Reasoning**:
# Print the `scraped_reviews` list to display the retrieved app reviews.

# %%
display(scraped_reviews)
# Out:
# [{'reviewId': 'e1c9b587-6b7a-4edb-99c6-d0a63cb195dd',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Awalnya sy kecewa karena langganan 3 bulan tapi hanya dapat 1 bulan. sy mencari2 layanan cust service spotify, akhirnya dapat. Caranya: 1.buka aplikasi spotify 2. klik profil 3. pengaturan dan privasi 4. tentang dan dukungan 5. dukungan. Awalnya sy chat dengan mesin, tapi karena masalah tidak terpecahkan, akhirnya sy terhubung dengan cs dan masalah terpecahkan, uang sy direfund full tidak sampai 1/2 jam,terima kasih. NB: harga premium apakah bisa diturunkan?, Rp 59900+ppn terlalu mahal untuk sy',
#   'score': 5,
#   'thumbsUpCount': 565,
#   'reviewCreatedVersion': '9.0.78.1116',
#   'at': datetime.datetime(2025, 9, 17, 13, 36, 31),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '9.0.78.1116'},
# ...

# %% [markdown]
# ## **4. Convert the data to CSV**
#
# Konversi data ulasan yang diambil menjadi DataFrame pandas dan simpan ke file CSV.

# %% [markdown]
# **Reasoning**:
# Convert the list of dictionaries containing the scraped reviews into a pandas DataFrame for easier manipulation and then save it as a CSV file.

# %%
reviews_df = pd.DataFrame(scraped_reviews)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1482482677.py in <cell line: 0>()
# ----> 1 reviews_df = pd.DataFrame(scraped_reviews)
#
# NameError: name 'pd' is not defined

# %%
# Save the DataFrame to a CSV file
# reviews_df.to_csv('spotify_reviews_id_id_2.csv', index=False)
reviews_df.to_csv('spotify_reviews_en_promax.csv', index=False)

# %%
combined_reviews_df = pd.concat([reviews_df, reviews_df2], ignore_index=True)
display(combined_reviews_df.head())
# Out:
#                                reviewId       userName  \
# 0  97b3a330-8135-4961-963b-d5b40aeaa80a  A Google user
# 1  39a62a75-3998-483e-aca2-8719d3f8dd57  A Google user
# 2  03c513ab-df54-42a2-aa3c-7502c086d875  A Google user
# 3  5f769b79-7d95-4129-8078-1dc62d8f2b2b  A Google user
# 4  fd4665c6-ed09-4af0-94a2-06b8f5e2d8c4  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  they fixed it, I was just really pissy yesterd...      5              1
# 1  Offline doesnt work, support doesnt help, just...      1              0
# 2  Super annoying ad experience! It feels like th...      1              5
# ...

# %%
combined_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              60000 non-null  object
#  1   userName              60000 non-null  object
#  2   userImage             60000 non-null  object
#  3   content               59998 non-null  object
#  4   score                 60000 non-null  int64
#  5   thumbsUpCount         60000 non-null  int64
#  6   reviewCreatedVersion  49594 non-null  object
#  7   at                    60000 non-null  datetime64[ns]
#  8   replyContent          7998 non-null   object
#  9   repliedAt             7998 non-null   datetime64[ns]
#  10  appVersion            49594 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 5.0+ MB

# %%
combined_reviews_df.duplicated().sum()
# Out:
# np.int64(29999)

# %%
reviews_df.head(10)
# Out:
#                                reviewId       userName  \
# 0  97b3a330-8135-4961-963b-d5b40aeaa80a  A Google user
# 1  39a62a75-3998-483e-aca2-8719d3f8dd57  A Google user
# 2  03c513ab-df54-42a2-aa3c-7502c086d875  A Google user
# 3  5f769b79-7d95-4129-8078-1dc62d8f2b2b  A Google user
# 4  fd4665c6-ed09-4af0-94a2-06b8f5e2d8c4  A Google user
# 5  85e05300-8cd8-486b-8772-e0a92d0ba2bb  A Google user
# 6  d110f146-bc57-49f3-b029-9426a29ed9e4  A Google user
# 7  ede27b9e-b0e1-40b9-a620-8e86bcd3634d  A Google user
# 8  2d6b215b-f1ad-4fa1-8db8-ccb43c6c684e  A Google user
# 9  96d05513-15cc-4e6f-8a3f-9765af513be0  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              30000 non-null  object
#  1   userName              30000 non-null  object
#  2   userImage             30000 non-null  object
#  3   content               29999 non-null  object
#  4   score                 30000 non-null  int64
#  5   thumbsUpCount         30000 non-null  int64
#  6   reviewCreatedVersion  24797 non-null  object
#  7   at                    30000 non-null  datetime64[ns]
#  8   replyContent          3999 non-null   object
#  9   repliedAt             3999 non-null   datetime64[ns]
#  10  appVersion            24797 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 2.5+ MB

# %%
reviews_df.describe(include='all')
# Out:
#                                     reviewId       userName  \
# count                                  30000          30000
# unique                                 30000              1
# top     abcca248-5947-4e6b-8ef5-abb003d8f58c  A Google user
# freq                                       1          30000
# mean                                     NaN            NaN
# min                                      NaN            NaN
# 25%                                      NaN            NaN
# 50%                                      NaN            NaN
# 75%                                      NaN            NaN
# max                                      NaN            NaN
# std                                      NaN            NaN
#
#                                                 userImage content  \
# count                                               30000   29999
# unique                                                  1   24282
# ...
