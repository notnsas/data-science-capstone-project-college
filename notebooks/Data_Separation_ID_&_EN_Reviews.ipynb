# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/data-science-capstone-project-college/blob/main/Data_Separation_ID_%26_EN_Reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_id = pd.read_csv('https://github.com/LatiefDataVisionary/data-science-capstone-project-college/raw/refs/heads/main/data/processed/reviews_labeled_id_tokenized.csv.zip')
df_en = pd.read_csv('https://github.com/LatiefDataVisionary/data-science-capstone-project-college/raw/refs/heads/main/data/processed/reviews_labeled_en_tokenized.csv.zip')

# %%
df_id.head()
# Out:
#                                              content  score  thumbsUpCount  \
# 0  lagu bukan hanya alunan nada tapi bisa jadi un...      1              2
# 1  iklan Mulu gak jelass apa apa harus premium ko...      1              0
# 2                           Terima kasih banyak 🙏👍👍👍      5              0
# 3  kok di aku mah gk bisa ada lirik ya sih tolong...      4              0
# 4                             sangat banyak lagu nya      5              0
#
#                                      cleaned_content sentiment_label
# 0  ['lagu', 'bukan', 'hanya', 'alunan', 'nada', '...        positive
# 1  ['iklan', 'mulu', 'tidak', 'jelass', 'apa', 'a...        negative
# 2                      ['terima', 'kasih', 'banyak']        positive
# 3  ['kok', 'di', 'aku', 'mah', 'gk', 'bisa', 'ada...        negative
# 4                ['sangat', 'banyak', 'lagu', 'nya']        positive

# %%
df_en.head()
# Out:
#                                              content  score  thumbsUpCount  \
# 0  they fixed it, I was just really pissy yesterd...      5              1
# 1  Offline doesnt work, support doesnt help, just...      1              0
# 2  Super annoying ad experience! It feels like th...      1              5
# 3                                                  👍      5              1
# 4                          super song for everything      5              0
#
#                                      cleaned_content sentiment_label
# 0  ['fixed', 'really', 'pissy', 'yesterday', 'cau...         neutral
# 1  ['offline', 'doesnt', 'work', 'support', 'does...        negative
# 2  ['super', 'annoying', 'ad', 'experience', 'fee...        positive
# 3                                                 []         neutral
# 4                    ['super', 'song', 'everything']        positive

# %%
sample_500_id = df_id.sample(n=500)
sample_500_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 26488 to 41473
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   content          500 non-null    object
#  1   score            500 non-null    int64
#  2   thumbsUpCount    500 non-null    int64
#  3   cleaned_content  500 non-null    object
#  4   sentiment_label  500 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 23.4+ KB

# %%
sample_500_en = df_en.sample(n=500)
sample_500_en.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 48462 to 63687
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   content          500 non-null    object
#  1   score            500 non-null    int64
#  2   thumbsUpCount    500 non-null    int64
#  3   cleaned_content  500 non-null    object
#  4   sentiment_label  500 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 23.4+ KB

# %%
import os

# Create the directory if it doesn't exist
os.makedirs('data/processed', exist_ok=True)

sample_500_id.to_csv('data/processed/sample_500_id.csv', index=False)
sample_500_en.to_csv('data/processed/sample_500_en.csv', index=False)
